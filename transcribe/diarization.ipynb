# %%
pip uninstall torch torchaudio torchvision

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
pip install pyannote.audio

# %%
from dotenv import load_dotenv
from pathlib import Path
import os
from huggingface_hub import login
parent_dir = Path.cwd().parent
load_dotenv(dotenv_path=parent_dir / ".env")
hf_token = os.getenv("HF_TOKEN")
login(token=hf_token)

# %%
from pyannote.audio import Pipeline
import pandas as pd

# Load pre-trained pipeline (make sure you are logged in with a valid token)
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization")

# Apply pipeline on the audio/video file
diarization = pipeline("../Poadcasts/audio.wav")

# Prepare data for DataFrame
segments = []

for turn, _, speaker in diarization.itertracks(yield_label=True):
    start_time = round(turn.start, 2)
    end_time = round(turn.end, 2)
    duration = round(end_time - start_time, 2)

    print(f"{start_time:.2f}s - {end_time:.2f}s: {speaker}")

    segments.append({
        "Start Time (s)": start_time,
        "End Time (s)": end_time,
        "Duration (s)": duration,
        "Speaker": speaker
    })

# Convert to DataFrame
df = pd.DataFrame(segments)

# Save to CSV
df.to_csv("diarization_segments.csv", index=False)

print("\nSaved diarization results to 'diarization_segments.csv'")
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.5.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\USER\.cache\torch\pyannote\models--pyannote--segmentation\snapshots\c4c8ceafcbb3a7a280c2d357aee9fbc9b0be7f9b\pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.3.2. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.8.0+cpu. Bad things might happen unless you revert torch to 1.x.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 8
#       5 pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization")
#       7 # Apply pipeline on the audio/video file
# ----> 8 diarization = pipeline("../Poadcasts/audio.wav")
#      10 # Prepare data for DataFrame
# ...

# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# aiohappyeyeballs          2.6.1
# aiosignal                 1.4.0
# anyio                     4.10.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# async-timeout             5.0.1
# attrs                     25.3.0
# av                        15.0.0
# babel                     2.17.0
# beautifulsoup4            4.13.4
# bleach                    6.2.0
# certifi                   2025.8.3
# cffi                      1.17.1
# charset-normalizer        3.4.2
# colorama                  0.4.6
# coloredlogs               15.0.1
# comm                      0.2.3
# contourpy                 1.3.2
# ctranslate2               4.6.0
# cycler                    0.12.1
# debugpy                   1.8.15
# decorator                 5.2.1
# defusedxml                0.7.1
# ...
